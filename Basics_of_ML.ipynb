# %% [markdown]
# ## What is machine learning?

# %% [markdown]
# Machine learning is the study of algorithms that can learn from experience. As a machine learning algorithm accumulates more experience, typically in the form of observational data or interactions with an environment, its performance improves.

# %% [markdown]
# In machine learning, the learning is the process by which we discover the right setting of the knobs for coercing the desired behavior from our model. In other words, we train our model with data.

# %% [markdown]
# ##### some core components that will follow us around, no matter what kind of machine learning problem we tackle:
#
# >The data that we can learn from.
#
# >A model of how to transform the data.
#
# >An objective function that quantifies how well (or badly) the model is doing.
#
# >An algorithm to adjust the model’s parameters to optimize the objective function.

# %% [markdown]
#  ###### In simple words, ML teaches systems to think and understand like humans by learning from the data.

# %% [markdown]
# ### Data

# %% [markdown]
# It might go without saying that you cannot do data science without data.
# >Generally, the more data we have, the easier our job becomes. When we have more data, we can train more powerful models and rely less heavily on preconceived assumptions.
#
# >Finally, it is not enough to have lots of data and to process it cleverly. We need the right data. If the data is full of mistakes, or if the chosen features are not predictive of the target quantity of interest, learning is going to fail. The situation is captured well by the cliché:garbage in, garbage out.

# %% [markdown]
# ### AI VS ML VS DL

# %% [markdown]
# ![AI-vs-ML-vs-Deep-Learning.png](attachment:45c2a170-270e-4bce-b1d1-7d1dd330e2c9.png)

# %% [markdown]
# ##### Types of Machine Learning

# %% [markdown]
# ![types of machine learning.png](attachment:6dfa778f-6b98-4c66-87de-c2e30ea10b01.png)
